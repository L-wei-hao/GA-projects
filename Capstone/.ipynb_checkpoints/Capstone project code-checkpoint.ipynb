# %% [markdown]
# ## Machine learning Algorithm Trader
#
# In this project, we will be using the OANDA v20 REST API
#
# <img style="float: left;" src="./images/api.png">

# %% [markdown]
# # Why forex over stocks?
#
#
# ![3advantage](./images/lvts.png)
#
# ### Liquidity
# The forex market is the largest and most liquid financial market. Daily activity often exceeds 4 trillion USD, with over 1.5 trillion of that conducted in the form of spot trading.
#
#
# ### Volatility
# Volatility boosts opportunity due to exchange rate fluctuations. Forex trading operates 24 hours a day, 5 days a week. The greatest liquidity occurs when operational hours in multiple time zones overlap.
#
#
# ### Tight Spreads
# Spreads in the forex market tend to be tighter (less), than the spreads applied to other, securities such as stocks. This makes OTC forex trading one of the most cost - effective means of investment trading.

# %%
#python packages required

# pip install v20  #OANDA V20 API
# pip install ujson
# pip install PyYAML
# pip install --index-url https://test.pypi.org/simple/ #tpqoa wrap up package

# %%
import pandas as pd
import tpqoa

# %%
#sensitive ID and password have been gitignored you will need to create your own config file 


api = tpqoa.tpqoa("oanda.cfg")

# %%
api.get_account_summary()
# Out:
# {'id': '101-003-23224294-001',
#  'alias': 'Primary',
#  'currency': 'SGD',
#  'balance': '100000.0086',
#  'createdByUserID': 23224294,
#  'createdTime': '2022-09-13T12:16:27.974338285Z',
#  'guaranteedStopLossOrderMode': 'ALLOWED',
#  'pl': '-267.7014',
#  'resettablePL': '-267.7014',
#  'resettablePLTime': '0',
#  'financing': '0.0',
#  'commission': '0.0',
#  'guaranteedExecutionFees': '0.0',
#  'marginRate': '0.05',
#  'openTradeCount': 0,
#  'openPositionCount': 0,
#  'pendingOrderCount': 0,
#  'hedgingEnabled': False,
#  'unrealizedPL': '0.0',
#  'NAV': '100000.0086',
#  'marginUsed': '0.0',
#  'marginAvailable': '100000.0086',
#  'positionValue': '0.0',
#  'marginCloseoutUnrealizedPL': '0.0',
#  'marginCloseoutNAV': '100000.0086',
#  'marginCloseoutMarginUsed': '0.0',
#  'marginCloseoutPercent': '0.0',
#  'marginCloseoutPositionValue': '0.0',
#  'withdrawalLimit': '100000.0086',
#  'marginCallMarginUsed': '0.0',
#  'marginCallPercent': '0.0',
#  'lastTransactionID': '20'}

# %%
#ensure the accunt type is the OANDA demo account
api.account_type
# Out:
# 'practice'

# %%
api.account_id
# Out:
# '101-003-23224294-001'

# %%
api.get_instruments()
# Out:
# [('Copper', 'XCU_USD'),
#  ('Wheat', 'WHEAT_USD'),
#  ('NZD/SGD', 'NZD_SGD'),
#  ('US SPX 500', 'SPX500_USD'),
#  ('USD/NOK', 'USD_NOK'),
#  ('UK 100', 'UK100_GBP'),
#  ('AUD/NZD', 'AUD_NZD'),
#  ('Silver', 'XAG_USD'),
#  ('EUR/HUF', 'EUR_HUF'),
#  ('Silver/EUR', 'XAG_EUR'),
#  ('Litecoin', 'LTC_USD'),
#  ('Silver/GBP', 'XAG_GBP'),
#  ('NZD/USD', 'NZD_USD'),
#  ('USD/CNH', 'USD_CNH'),
#  ('CHF/ZAR', 'CHF_ZAR'),
#  ('GBP/NZD', 'GBP_NZD'),
#  ('US 10Y T-Note', 'USB10Y_USD'),
#  ('Hong Kong 33', 'HK33_HKD'),
#  ('US 5Y T-Note', 'USB05Y_USD'),
#  ('US 2Y T-Note', 'USB02Y_USD'),
#  ('Bund', 'DE10YB_EUR'),
#  ('US Russ 2000', 'US2000_USD'),
#  ('US T-Bond', 'USB30Y_USD'),
#  ('USD/CAD', 'USD_CAD'),
#  ('ZAR/JPY', 'ZAR_JPY'),
#  ('Silver/JPY', 'XAG_JPY'),
#  ('Ether', 'ETH_USD'),
#  ('SGD/JPY', 'SGD_JPY'),
#  ('GBP/ZAR', 'GBP_ZAR'),
#  ('USD/JPY', 'USD_JPY'),
#  ('EUR/TRY', 'EUR_TRY'),
#  ('Bitcoin', 'BTC_USD'),
#  ('EUR/CZK', 'EUR_CZK'),
#  ('EUR/JPY', 'EUR_JPY'),
#  ('Taiwan Index', 'TWIX_USD'),
#  ('AUD/SGD', 'AUD_SGD'),
#  ('Silver/NZD', 'XAG_NZD'),
#  ('West Texas Oil', 'WTICO_USD'),
#  ('Silver/AUD', 'XAG_AUD'),
#  ('EUR/NZD', 'EUR_NZD'),
#  ('GBP/HKD', 'GBP_HKD'),
#  ('CHF/JPY', 'CHF_JPY'),
#  ('Gold/AUD', 'XAU_AUD'),
#  ('EUR/HKD', 'EUR_HKD'),
#  ('Gold/HKD', 'XAU_HKD'),
#  ('Gold/JPY', 'XAU_JPY'),
#  ('USD/THB', 'USD_THB'),
#  ('GBP/CHF', 'GBP_CHF'),
#  ('CAD/JPY', 'CAD_JPY'),
#  ('NZD/CHF', 'NZD_CHF'),
#  ('Spain 35', 'ESPIX_EUR'),
#  ('AUD/HKD', 'AUD_HKD'),
#  ('Silver/HKD', 'XAG_HKD'),
#  ('USD/CHF', 'USD_CHF'),
#  ('Silver/CHF', 'XAG_CHF'),
#  ('Bitcoin Cash', 'BCH_USD'),
#  ('AUD/USD', 'AUD_USD'),
#  ('GBP/JPY', 'GBP_JPY'),
#  ('USD/TRY', 'USD_TRY'),
#  ('US Nas 100', 'NAS100_USD'),
#  ('TRY/JPY', 'TRY_JPY'),
#  ('USD/SGD', 'USD_SGD'),
#  ('EUR/SEK', 'EUR_SEK'),
#  ('HKD/JPY', 'HKD_JPY'),
#  ('AUD/CHF', 'AUD_CHF'),
#  ('Gold/Silver', 'XAU_XAG'),
#  ('SGD/CHF', 'SGD_CHF'),
#  ('Soybeans', 'SOYBN_USD'),
#  ('Corn', 'CORN_USD'),
#  ('USD/PLN', 'USD_PLN'),
#  ('GBP/AUD', 'GBP_AUD'),
#  ('Gold/SGD', 'XAU_SGD'),
#  ('AUD/JPY', 'AUD_JPY'),
#  ('EUR/ZAR', 'EUR_ZAR'),
#  ('China H Shares', 'CHINAH_HKD'),
#  ('Singapore 30', 'SG30_SGD'),
#  ('EUR/USD', 'EUR_USD'),
#  ('EUR/CAD', 'EUR_CAD'),
#  ('USD/HUF', 'USD_HUF'),
#  ('Netherlands 25', 'NL25_EUR'),
#  ('EUR/CHF', 'EUR_CHF'),
#  ('UK 10Y Gilt', 'UK10YB_GBP'),
#  ('NZD/CAD', 'NZD_CAD'),
#  ('EUR/SGD', 'EUR_SGD'),
#  ('USD/INR', 'USD_INR'),
#  ('Gold/NZD', 'XAU_NZD'),
#  ('Gold/GBP', 'XAU_GBP'),
#  ('NZD/JPY', 'NZD_JPY'),
#  ('CHF/HKD', 'CHF_HKD'),
#  ('Australia 200', 'AU200_AUD'),
#  ('USD/DKK', 'USD_DKK'),
#  ('EUR/AUD', 'EUR_AUD'),
#  ('Gold/CAD', 'XAU_CAD'),
#  ('Gold/CHF', 'XAU_CHF'),
#  ('Japan 225', 'JP225_USD'),
#  ('Silver/CAD', 'XAG_CAD'),
#  ('USD/ZAR', 'USD_ZAR'),
#  ('USD/CZK', 'USD_CZK'),
#  ('China A50', 'CN50_USD'),
#  ('Europe 50', 'EU50_EUR'),
#  ('Silver/SGD', 'XAG_SGD'),
#  ('France 40', 'FR40_EUR'),
#  ('GBP/SGD', 'GBP_SGD'),
#  ('USD/SEK', 'USD_SEK'),
#  ('USD/MXN', 'USD_MXN'),
#  ('GBP/USD', 'GBP_USD'),
#  ('EUR/DKK', 'EUR_DKK'),
#  ('Natural Gas', 'NATGAS_USD'),
#  ('CAD/CHF', 'CAD_CHF'),
#  ('EUR/GBP', 'EUR_GBP'),
#  ('CAD/HKD', 'CAD_HKD'),
#  ('Switzerland 20', 'CH20_CHF'),
#  ('Brent Crude Oil', 'BCO_USD'),
#  ('EUR/NOK', 'EUR_NOK'),
#  ('Gold', 'XAU_USD'),
#  ('Palladium', 'XPD_USD'),
#  ('Platinum', 'XPT_USD'),
#  ('GBP/CAD', 'GBP_CAD'),
#  ('Gold/EUR', 'XAU_EUR'),
#  ('Germany 30', 'DE30_EUR'),
#  ('NZD/HKD', 'NZD_HKD'),
#  ('GBP/PLN', 'GBP_PLN'),
#  ('US Wall St 30', 'US30_USD'),
#  ('Japan 225 (JPY)', 'JP225Y_JPY'),
#  ('EUR/PLN', 'EUR_PLN'),
#  ('Sugar', 'SUGAR_USD'),
#  ('AUD/CAD', 'AUD_CAD'),
#  ('USD/HKD', 'USD_HKD'),
#  ('CAD/SGD', 'CAD_SGD')]

# %%
instr = api.get_instruments()

# %%
len(instr)
# Out:
# 129

# %%
instr[0]
# Out:
# ('Copper', 'XCU_USD')

# %% [markdown]
# ## Getting Historical Data

# %%
#lets see how to use .get_history 
help(api.get_history)
# Out:
# Help on method get_history in module tpqoa.tpqoa:
#
# get_history(instrument, start, end, granularity, price) method of tpqoa.tpqoa.tpqoa instance
#     Retrieves historical data for instrument.
#
#     Parameters
#     ==========
#     instrument: string
#         valid instrument name
#     start, end: datetime, str
#         Python datetime or string objects for start and end
#     granularity: string
#         a string like 'S5', 'M1' or 'D'
#     price: string
#         one of 'A' (ask) or 'B' (bid)
#
#     Returns
#     =======
#     data: pd.DataFrame
#         pandas DataFrame object with data

# %%
api.get_history("EUR_USD", "2022-08-03", "2022-08-05", "H1", "A")
# 2022-08-04 22:00:00+00:00  1.02494
# 2022-08-04 23:00:00+00:00  1.02484

# %%
api.get_history("EUR_USD", "2022-08-03", "2022-08-05", "H12", "A")
# Out:
#                            volume  complete        o        h        l  \
# time
# 2022-08-02 21:00:00+00:00   51042      True  1.01694  1.01947  1.01508
# 2022-08-03 09:00:00+00:00   75581      True  1.01887  1.02111  1.01235
# 2022-08-03 21:00:00+00:00   37204      True  1.01710  1.01950  1.01550
# 2022-08-04 09:00:00+00:00   75057      True  1.01924  1.02547  1.01612
# 2022-08-04 21:00:00+00:00   35443      True  1.02518  1.02532  1.02192
#
#                                  c
# time
# 2022-08-02 21:00:00+00:00  1.01889
# 2022-08-03 09:00:00+00:00  1.01703
# 2022-08-03 21:00:00+00:00  1.01925
# 2022-08-04 09:00:00+00:00  1.02478
# 2022-08-04 21:00:00+00:00  1.02246

# %%
api.get_history("EUR_USD", "2022-08-03", "2022-08-05", "M1", "A")
# Out:
# C:\Users\v-weihaoloh\Anaconda3\envs\anacondabackup\lib\site-packages\tpqoa\tpqoa.py:161: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   data = data.append(batch)
# C:\Users\v-weihaoloh\Anaconda3\envs\anacondabackup\lib\site-packages\tpqoa\tpqoa.py:161: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   data = data.append(batch)
#                            volume  complete        o        h        l  \
# time
# 2022-08-03 00:00:00+00:00     147      True  1.01575  1.01609  1.01572
# 2022-08-03 00:01:00+00:00     112      True  1.01585  1.01600  1.01583
# 2022-08-03 00:02:00+00:00     120      True  1.01586  1.01621  1.01586
# 2022-08-03 00:03:00+00:00     108      True  1.01620  1.01626  1.01607
# 2022-08-03 00:04:00+00:00     114      True  1.01615  1.01630  1.01608
# ...                           ...       ...      ...      ...      ...
# 2022-08-04 23:55:00+00:00      36      True  1.02497  1.02497  1.02481
# 2022-08-04 23:56:00+00:00      28      True  1.02483  1.02489  1.02483
# 2022-08-04 23:57:00+00:00      28      True  1.02487  1.02487  1.02482
# 2022-08-04 23:58:00+00:00      26      True  1.02484  1.02486  1.02482
# 2022-08-04 23:59:00+00:00      35      True  1.02484  1.02494  1.02483
#
#                                  c
# time
# 2022-08-03 00:00:00+00:00  1.01583
# 2022-08-03 00:01:00+00:00  1.01588
# 2022-08-03 00:02:00+00:00  1.01621
# 2022-08-03 00:03:00+00:00  1.01615
# 2022-08-03 00:04:00+00:00  1.01627
# ...                            ...
# 2022-08-04 23:55:00+00:00  1.02482
# 2022-08-04 23:56:00+00:00  1.02489
# 2022-08-04 23:57:00+00:00  1.02484
# 2022-08-04 23:58:00+00:00  1.02485
# 2022-08-04 23:59:00+00:00  1.02484
#
# [2855 rows x 6 columns]

# %%
api.get_history("EUR_USD", "2022-08-03", "2022-08-04", "S5", "A")
# Out:
# C:\Users\v-weihaoloh\Anaconda3\envs\anacondabackup\lib\site-packages\tpqoa\tpqoa.py:161: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   data = data.append(batch)
# C:\Users\v-weihaoloh\Anaconda3\envs\anacondabackup\lib\site-packages\tpqoa\tpqoa.py:161: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   data = data.append(batch)
# C:\Users\v-weihaoloh\Anaconda3\envs\anacondabackup\lib\site-packages\tpqoa\tpqoa.py:161: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   data = data.append(batch)
# C:\Users\v-weihaoloh\Anaconda3\envs\anacondabackup\lib\site-packages\tpqoa\tpqoa.py:161: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   data = data.append(batch)
# C:\Users\v-weihaoloh\Anaconda3\envs\anacondabackup\lib\site-packages\tpqoa\tpqoa.py:161: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   data = data.append(batch)
# C:\Users\v-weihaoloh\Anaconda3\envs\anacondabackup\lib\site-packages\tpqoa\tpqoa.py:161: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   data = data.append(batch)
#                            volume  complete        o        h        l  \
# time
# 2022-08-03 00:00:00+00:00      28      True  1.01575  1.01593  1.01572
# 2022-08-03 00:00:05+00:00       5      True  1.01588  1.01590  1.01588
# 2022-08-03 00:00:10+00:00      10      True  1.01589  1.01600  1.01589
# 2022-08-03 00:00:15+00:00      17      True  1.01600  1.01600  1.01593
# 2022-08-03 00:00:20+00:00       6      True  1.01600  1.01601  1.01599
# ...                           ...       ...      ...      ...      ...
# 2022-08-03 23:59:30+00:00       6      True  1.01584  1.01586  1.01579
# 2022-08-03 23:59:35+00:00       5      True  1.01579  1.01581  1.01579
# 2022-08-03 23:59:40+00:00       4      True  1.01581  1.01583  1.01579
# 2022-08-03 23:59:45+00:00       4      True  1.01576  1.01580  1.01576
# 2022-08-03 23:59:50+00:00       2      True  1.01577  1.01577  1.01575
#
#                                  c
# time
# 2022-08-03 00:00:00+00:00  1.01589
# 2022-08-03 00:00:05+00:00  1.01590
# 2022-08-03 00:00:10+00:00  1.01598
# 2022-08-03 00:00:15+00:00  1.01600
# 2022-08-03 00:00:20+00:00  1.01600
# ...                            ...
# 2022-08-03 23:59:30+00:00  1.01579
# 2022-08-03 23:59:35+00:00  1.01580
# 2022-08-03 23:59:40+00:00  1.01579
# 2022-08-03 23:59:45+00:00  1.01579
# 2022-08-03 23:59:50+00:00  1.01575
#
# [15239 rows x 6 columns]

# %%
api.get_instruments()
# Out:
# [('Copper', 'XCU_USD'),
#  ('Wheat', 'WHEAT_USD'),
#  ('NZD/SGD', 'NZD_SGD'),
#  ('US SPX 500', 'SPX500_USD'),
#  ('USD/NOK', 'USD_NOK'),
#  ('UK 100', 'UK100_GBP'),
#  ('AUD/NZD', 'AUD_NZD'),
#  ('Silver', 'XAG_USD'),
#  ('EUR/HUF', 'EUR_HUF'),
#  ('Silver/EUR', 'XAG_EUR'),
#  ('Litecoin', 'LTC_USD'),
#  ('Silver/GBP', 'XAG_GBP'),
#  ('NZD/USD', 'NZD_USD'),
#  ('USD/CNH', 'USD_CNH'),
#  ('CHF/ZAR', 'CHF_ZAR'),
#  ('GBP/NZD', 'GBP_NZD'),
#  ('US 10Y T-Note', 'USB10Y_USD'),
#  ('Hong Kong 33', 'HK33_HKD'),
#  ('US 5Y T-Note', 'USB05Y_USD'),
#  ('US 2Y T-Note', 'USB02Y_USD'),
#  ('Bund', 'DE10YB_EUR'),
#  ('US Russ 2000', 'US2000_USD'),
#  ('US T-Bond', 'USB30Y_USD'),
#  ('USD/CAD', 'USD_CAD'),
#  ('ZAR/JPY', 'ZAR_JPY'),
#  ('Silver/JPY', 'XAG_JPY'),
#  ('Ether', 'ETH_USD'),
#  ('SGD/JPY', 'SGD_JPY'),
#  ('GBP/ZAR', 'GBP_ZAR'),
#  ('USD/JPY', 'USD_JPY'),
#  ('EUR/TRY', 'EUR_TRY'),
#  ('Bitcoin', 'BTC_USD'),
#  ('EUR/CZK', 'EUR_CZK'),
#  ('EUR/JPY', 'EUR_JPY'),
#  ('Taiwan Index', 'TWIX_USD'),
#  ('AUD/SGD', 'AUD_SGD'),
#  ('Silver/NZD', 'XAG_NZD'),
#  ('West Texas Oil', 'WTICO_USD'),
#  ('Silver/AUD', 'XAG_AUD'),
#  ('EUR/NZD', 'EUR_NZD'),
#  ('GBP/HKD', 'GBP_HKD'),
#  ('CHF/JPY', 'CHF_JPY'),
#  ('Gold/AUD', 'XAU_AUD'),
#  ('EUR/HKD', 'EUR_HKD'),
#  ('Gold/HKD', 'XAU_HKD'),
#  ('Gold/JPY', 'XAU_JPY'),
#  ('USD/THB', 'USD_THB'),
#  ('GBP/CHF', 'GBP_CHF'),
#  ('CAD/JPY', 'CAD_JPY'),
#  ('NZD/CHF', 'NZD_CHF'),
#  ('Spain 35', 'ESPIX_EUR'),
#  ('AUD/HKD', 'AUD_HKD'),
#  ('Silver/HKD', 'XAG_HKD'),
#  ('USD/CHF', 'USD_CHF'),
#  ('Silver/CHF', 'XAG_CHF'),
#  ('Bitcoin Cash', 'BCH_USD'),
#  ('AUD/USD', 'AUD_USD'),
#  ('GBP/JPY', 'GBP_JPY'),
#  ('USD/TRY', 'USD_TRY'),
#  ('US Nas 100', 'NAS100_USD'),
#  ('TRY/JPY', 'TRY_JPY'),
#  ('USD/SGD', 'USD_SGD'),
#  ('EUR/SEK', 'EUR_SEK'),
#  ('HKD/JPY', 'HKD_JPY'),
#  ('AUD/CHF', 'AUD_CHF'),
#  ('Gold/Silver', 'XAU_XAG'),
#  ('SGD/CHF', 'SGD_CHF'),
#  ('Soybeans', 'SOYBN_USD'),
#  ('Corn', 'CORN_USD'),
#  ('USD/PLN', 'USD_PLN'),
#  ('GBP/AUD', 'GBP_AUD'),
#  ('Gold/SGD', 'XAU_SGD'),
#  ('AUD/JPY', 'AUD_JPY'),
#  ('EUR/ZAR', 'EUR_ZAR'),
#  ('China H Shares', 'CHINAH_HKD'),
#  ('Singapore 30', 'SG30_SGD'),
#  ('EUR/USD', 'EUR_USD'),
#  ('EUR/CAD', 'EUR_CAD'),
#  ('USD/HUF', 'USD_HUF'),
#  ('Netherlands 25', 'NL25_EUR'),
#  ('EUR/CHF', 'EUR_CHF'),
#  ('UK 10Y Gilt', 'UK10YB_GBP'),
#  ('NZD/CAD', 'NZD_CAD'),
#  ('EUR/SGD', 'EUR_SGD'),
#  ('USD/INR', 'USD_INR'),
#  ('Gold/NZD', 'XAU_NZD'),
#  ('Gold/GBP', 'XAU_GBP'),
#  ('NZD/JPY', 'NZD_JPY'),
#  ('CHF/HKD', 'CHF_HKD'),
#  ('Australia 200', 'AU200_AUD'),
#  ('USD/DKK', 'USD_DKK'),
#  ('EUR/AUD', 'EUR_AUD'),
#  ('Gold/CAD', 'XAU_CAD'),
#  ('Gold/CHF', 'XAU_CHF'),
#  ('Japan 225', 'JP225_USD'),
#  ('Silver/CAD', 'XAG_CAD'),
#  ('USD/ZAR', 'USD_ZAR'),
#  ('USD/CZK', 'USD_CZK'),
#  ('China A50', 'CN50_USD'),
#  ('Europe 50', 'EU50_EUR'),
#  ('Silver/SGD', 'XAG_SGD'),
#  ('France 40', 'FR40_EUR'),
#  ('GBP/SGD', 'GBP_SGD'),
#  ('USD/SEK', 'USD_SEK'),
#  ('USD/MXN', 'USD_MXN'),
#  ('GBP/USD', 'GBP_USD'),
#  ('EUR/DKK', 'EUR_DKK'),
#  ('Natural Gas', 'NATGAS_USD'),
#  ('CAD/CHF', 'CAD_CHF'),
#  ('EUR/GBP', 'EUR_GBP'),
#  ('CAD/HKD', 'CAD_HKD'),
#  ('Switzerland 20', 'CH20_CHF'),
#  ('Brent Crude Oil', 'BCO_USD'),
#  ('EUR/NOK', 'EUR_NOK'),
#  ('Gold', 'XAU_USD'),
#  ('Palladium', 'XPD_USD'),
#  ('Platinum', 'XPT_USD'),
#  ('GBP/CAD', 'GBP_CAD'),
#  ('Gold/EUR', 'XAU_EUR'),
#  ('Germany 30', 'DE30_EUR'),
#  ('NZD/HKD', 'NZD_HKD'),
#  ('GBP/PLN', 'GBP_PLN'),
#  ('US Wall St 30', 'US30_USD'),
#  ('Japan 225 (JPY)', 'JP225Y_JPY'),
#  ('EUR/PLN', 'EUR_PLN'),
#  ('Sugar', 'SUGAR_USD'),
#  ('AUD/CAD', 'AUD_CAD'),
#  ('USD/HKD', 'USD_HKD'),
#  ('CAD/SGD', 'CAD_SGD')]

# %%
api.get_history("SPX500_USD", "2022-08-03", "2022-08-04", "H1", "A")
# Out:
#                            volume  complete       o       h       l       c
# time
# 2022-08-03 00:00:00+00:00    2163      True  4091.1  4095.4  4082.4  4087.9
# 2022-08-03 01:00:00+00:00    2033      True  4087.6  4098.4  4087.1  4095.9
# 2022-08-03 02:00:00+00:00    1212      True  4096.4  4100.6  4094.1  4097.4
# 2022-08-03 03:00:00+00:00     878      True  4097.4  4099.4  4095.6  4097.4
# 2022-08-03 04:00:00+00:00     726      True  4097.1  4102.9  4096.6  4098.4
# 2022-08-03 05:00:00+00:00    1089      True  4098.6  4104.4  4098.4  4102.4
# 2022-08-03 06:00:00+00:00    1162      True  4101.6  4105.6  4098.6  4100.9
# 2022-08-03 07:00:00+00:00    3444      True  4100.6  4101.6  4092.4  4095.4
# 2022-08-03 08:00:00+00:00    1731      True  4095.1  4102.4  4090.6  4100.1
# 2022-08-03 09:00:00+00:00    1333      True  4100.1  4111.4  4098.9  4106.9
# 2022-08-03 10:00:00+00:00    1271      True  4106.9  4110.1  4104.1  4106.9
# 2022-08-03 11:00:00+00:00    1294      True  4106.6  4113.4  4105.1  4111.1

# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Input In [28], in <cell line: 1>()
# ----> 1 api.stream_data('EUR_USD')
#
# File ~\Anaconda3\envs\anacondabackup\lib\site-packages\tpqoa\tpqoa.py:208, in tpqoa.stream_data(self, instrument, stop, ret)
#     204 response = self.ctx_stream.pricing.stream(
#     205     self.account_id, snapshot=True,
#     206     instruments=instrument)
#     207 msgs = []
# --> 208 for msg_type, msg in response.parts():
#     209     msgs.append(msg)
#     210     # print(msg_type, msg)
#
# File ~\Anaconda3\envs\anacondabackup\lib\site-packages\v20\response.py:52, in Response.parts(self)
#      49     return
#      51 try:
# ---> 52     for line in self.lines:
#      53         yield parser(line)
#      54 except requests.exceptions.ConnectionError:
#
# File ~\Anaconda3\envs\anacondabackup\lib\site-packages\requests\models.py:804, in Response.iter_lines(self, chunk_size, decode_unicode, delimiter)
#     795 """Iterates over the response data, one line at a time.  When
#     796 stream=True is set on the request, this avoids reading the
#     797 content at once into memory for large responses.
#     798
#     799 .. note:: This method is not reentrant safe.
#     800 """
#     802 pending = None
# --> 804 for chunk in self.iter_content(chunk_size=chunk_size, decode_unicode=decode_unicode):
#     806     if pending is not None:
#     807         chunk = pending + chunk
#
# File ~\Anaconda3\envs\anacondabackup\lib\site-packages\requests\models.py:760, in Response.iter_content.<locals>.generate()
#     758 if hasattr(self.raw, 'stream'):
#     759     try:
# --> 760         for chunk in self.raw.stream(chunk_size, decode_content=True):
#     761             yield chunk
#     762     except ProtocolError as e:
#
# File ~\Anaconda3\envs\anacondabackup\lib\site-packages\urllib3\response.py:575, in HTTPResponse.stream(self, amt, decode_content)
#     559 """
#     560 A generator wrapper for the read() method. A call will block until
#     561 ``amt`` bytes have been read from the connection or until the
#    (...)
#     572     'content-encoding' header.
#     573 """
#     574 if self.chunked and self.supports_chunked_reads():
# --> 575     for line in self.read_chunked(amt, decode_content=decode_content):
#     576         yield line
#     577 else:
#
# File ~\Anaconda3\envs\anacondabackup\lib\site-packages\urllib3\response.py:767, in HTTPResponse.read_chunked(self, amt, decode_content)
#     764     return
#     766 while True:
# --> 767     self._update_chunk_length()
#     768     if self.chunk_left == 0:
#     769         break
#
# File ~\Anaconda3\envs\anacondabackup\lib\site-packages\urllib3\response.py:697, in HTTPResponse._update_chunk_length(self)
#     695 if self.chunk_left is not None:
#     696     return
# --> 697 line = self._fp.fp.readline()
#     698 line = line.split(b";", 1)[0]
#     699 try:
#
# File ~\Anaconda3\envs\anacondabackup\lib\socket.py:704, in SocketIO.readinto(self, b)
#     702 while True:
#     703     try:
# --> 704         return self._sock.recv_into(b)
#     705     except timeout:
#     706         self._timeout_occurred = True
#
# File ~\Anaconda3\envs\anacondabackup\lib\ssl.py:1241, in SSLSocket.recv_into(self, buffer, nbytes, flags)
#    1237     if flags != 0:
#    1238         raise ValueError(
#    1239           "non-zero flags not allowed in calls to recv_into() on %s" %
#    1240           self.__class__)
# -> 1241     return self.read(nbytes, buffer)
#    1242 else:
#    1243     return super().recv_into(buffer, nbytes, flags)
#
# File ~\Anaconda3\envs\anacondabackup\lib\ssl.py:1099, in SSLSocket.read(self, len, buffer)
#    1097 try:
#    1098     if buffer is not None:
# -> 1099         return self._sslobj.read(len, buffer)
#    1100     else:
#    1101         return self._sslobj.read(len)
#
# KeyboardInterrupt:

# %%
api.stop_stream()

# %% [markdown]
# ## Creating Orders and Executing Trades

# %%
# api.create_order(instrument = "EUR_USD", units = 100000, sl_distance= 0.1)

# %%
# api.create_order(instrument = "EUR_USD", units = -100000, sl_distance= 0.1)

# %%
# api.get_account_summary()

# %%
# api.get_transactions(tid = 24)

# %%
# api.print_transactions(tid = 26-1)
